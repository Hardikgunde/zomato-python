# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
import seaborn as sns

# %%
D1=pd.read_csv('zomato.csv',encoding='latin1')
D1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
s1=pd.read_csv('Country-Code.csv',encoding='latin1')

# %%
s1
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
pd.merge(D1,s1,on='Country Code',how='left')
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
D1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
D1.isnull()
# Out:
#       Restaurant ID  Restaurant Name  Country Code   City  Address  Locality  \
# 0             False            False         False  False    False     False
# 1             False            False         False  False    False     False
# 2             False            False         False  False    False     False
# 3             False            False         False  False    False     False
# 4             False            False         False  False    False     False
# ...             ...              ...           ...    ...      ...       ...
# 9546          False            False         False  False    False     False
# 9547          False            False         False  False    False     False
# 9548          False            False         False  False    False     False
# 9549          False            False         False  False    False     False
# 9550          False            False         False  False    False     False
#
# ...

# %%
D1.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
len(D1)
# Out:
# 9551

# %%
D1.isnull().sum()/9551
# Out:
# Restaurant ID           0.000000
# Restaurant Name         0.000000
# Country Code            0.000000
# City                    0.000000
# Address                 0.000000
# Locality                0.000000
# Locality Verbose        0.000000
# Longitude               0.000000
# Latitude                0.000000
# Cuisines                0.000942
# Average Cost for two    0.000000
# Currency                0.000000
# Has Table booking       0.000000
# Has Online delivery     0.000000
# Is delivering now       0.000000
# Switch to order menu    0.000000
# Price range             0.000000
# Aggregate rating        0.000000
# Rating color            0.000000
# Rating text             0.000000
# Votes                   0.000000
# dtype: float64

# %%
D1.dropna(inplace=True)

# %%
D1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
D1.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
D1['Has Online delivery'].value_counts().plot(kind='bar')
plt.grid()
plt.show()

# %%
t1=D1['Cuisines'].mode()[0]

# %%
t1
# Out:
# 'North Indian'

# %%
sns.histplot(data=D1,x='Aggregate rating')
plt.show()

# %%
a=D1['Aggregate rating'].median()

# %%
a
# Out:
# 3.2

# %%
D1['Aggregate rating'].fillna(D1['Aggregate rating'].median(),inplace=True)

# %%
D1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
D1.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
D1.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
D1.drop(('Locality Verbose'),axis=1,inplace=True)

# %%
D1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
D1['Price range'].unique()
# Out:
# array([3, 4, 2, 1], dtype=int64)

# %%
mode=D1['Country Code'].mode()[0]

# %%
mode
# Out:
# 1

# %%
D1['Currency'].fillna(mode,inplace=True)

# %%
D1.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
D1.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
sns.barplot(data=D1,x='Price range',y='Votes',hue='Rating text')
plt.grid()

# %%
sns.boxplot(data=D1,x='Price range',y='Rating color',hue='Rating text')
plt.show()

# %%
mode=D1['Country Code'].mode()[0]

# %%
mode
# Out:
# 1

# %%
f1=D1[D1['Country Code']==1]

# %%
f1
# Out:
#       Restaurant ID                        Restaurant Name  Country Code  \
# 624         3400025                             Jahanpanah             1
# 625         3400341                    Rangrezz Restaurant             1
# 626         3400005                Time2Eat - Mama Chicken             1
# 627         3400021  Chokho Jeeman Marwari Jain Bhojanalya             1
# 628         3400017                         Pinch Of Spice             1
# ...             ...                                    ...           ...
# 9271        2800100                               D Cabana             1
# 9272        2800418                               Kaloreez             1
# 9273        2800881                                Plot 17             1
# 9274        2800042                       Vista - The Park             1
# 9275        2800019               Flying Spaghetti Monster             1
#
#        City                                            Address  \
# ...

# %%
D1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9542 entries, 0 to 9550
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9542 non-null   int64
#  1   Restaurant Name       9542 non-null   object
#  2   Country Code          9542 non-null   int64
#  3   City                  9542 non-null   object
#  4   Address               9542 non-null   object
#  5   Locality              9542 non-null   object
#  6   Longitude             9542 non-null   float64
#  7   Latitude              9542 non-null   float64
#  8   Cuisines              9542 non-null   object
#  9   Average Cost for two  9542 non-null   int64
#  10  Currency              9542 non-null   object
#  11  Has Table booking     9542 non-null   object
#  12  Has Online delivery   9542 non-null   object
#  13  Is delivering now     9542 non-null   object
#  14  Switch to order menu  9542 non-null   object
# ...

# %%
sns.barplot(data=f1,x='Price range',y='Votes',hue='Rating text')
plt.grid()

# %%
f1['Has Online delivery'].value_counts().plot(kind='bar')
plt.grid()
plt.show()

# %%
f1['Price range'].value_counts().plot(kind='pie',autopct='%i%%',wedgeprops={'edgecolor':'k'})
plt.show()

# %%
sns.boxplot(data=f1,x='Aggregate rating')
plt.show()

# %%
mode=f1['City'].mode()[0]

# %%
mode
# Out:
# 'New Delhi'

# %%
z1=f1[f1['City']=='New Delhi']

# %%
z1
# Out:
#       Restaurant ID       Restaurant Name  Country Code       City  \
# 2560       18287358            Food Cloud             1  New Delhi
# 2561       18216944             Burger.in             1  New Delhi
# 2562         313333       Days of the Raj             1  New Delhi
# 2563       18384127        Dilli Ka Dhaba             1  New Delhi
# 2564            582             Govardhan             1  New Delhi
# ...             ...                   ...           ...        ...
# 8028       18445274          Motu N Patlu             1  New Delhi
# 8029       18168147        S.K. Fast Food             1  New Delhi
# 8030       18429375    Sufiyan Restaurant             1  New Delhi
# 8031         310479       The Relax Point             1  New Delhi
# 8032       18212160  Zareen's Dastarkhwan             1  New Delhi
#
#                                                 Address     Locality  \
# 2560                              Aaya Nagar, New Delhi   Aaya Nagar
# ...

# %%
z1.head()
# Out:
#       Restaurant ID  Restaurant Name  Country Code       City  \
# 2560       18287358       Food Cloud             1  New Delhi
# 2561       18216944        Burger.in             1  New Delhi
# 2562         313333  Days of the Raj             1  New Delhi
# 2563       18384127   Dilli Ka Dhaba             1  New Delhi
# 2564            582        Govardhan             1  New Delhi
#
#                                                 Address    Locality  \
# 2560                              Aaya Nagar, New Delhi  Aaya Nagar
# 2561        84, Near Honda Showroom, Adchini, New Delhi     Adchini
# 2562  81/3, 1st Floor, Qutub Residency, Adchini, New...     Adchini
# 2563  66 A, Ground Floor, Sri Aurobindo Marg, Adchin...     Adchini
# 2564  84, Adjacent Hero Motor Bike Showroom, Main Me...     Adchini
#
#       Longitude   Latitude                             Cuisines  \
# 2560   0.000000   0.000000                       Cuisine Varies
# ...

# %%
z1.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   5.473000e+03        5473.0  5473.000000  5473.000000
# mean    8.275258e+06           1.0    73.903792    27.398205
# std     9.038827e+06           0.0    15.596506     5.778869
# min     5.300000e+01           1.0     0.000000     0.000000
# 25%     9.588000e+03           1.0    77.139505    28.557430
# 50%     3.113310e+05           1.0    77.204210    28.621372
# 75%     1.835680e+07           1.0    77.240761    28.654577
# max     1.850062e+07           1.0    77.339139    35.000000
#
#        Average Cost for two  Price range  Aggregate rating        Votes
# count           5473.000000  5473.000000       5473.000000  5473.000000
# mean             596.088069     1.621597          2.438845   114.807236
# std              635.311854     0.820218          1.500079   353.842279
# min               50.000000     1.000000          0.000000     0.000000
# ...

# %%
sns.boxplot(data=z1,x='Price range')
# Out:
# <AxesSubplot:xlabel='Price range'>

# %%
sns.boxplot(data=z1,x='Aggregate rating',y='Rating color')
plt.show()

# %%
df1=z1[(z1['Aggregate rating']<5)&(z1['Aggregate rating']>3)]
sns.boxplot(data=z1,x='Aggregate rating',y='Rating text')
plt.show()

# %%
pd.crosstab(z1['Restaurant Name'],z1['Cuisines'])
# Out:
# Cuisines                Afghani  Afghani, Mughlai, Chinese  \
# Restaurant Name
# #InstaFreeze                  0                          0
# #OFF Campus                   0                          0
# #hashtag                      0                          0
# 13 Cafe                       0                          0
# 17 Degree Food Service        0                          0
# ...                         ...                        ...
# deliKitchen                   0                          0
# hug!                          0                          0
# iGNiTE                        0                          0
# t Lounge by Dilmah            0                          0
# {Niche} - Cafe & Bar          0                          0
#
# Cuisines                Afghani, North Indian, Pakistani, Arabian  American  \
# Restaurant Name
# #InstaFreeze                                                    0         0
# ...

# %%
sns.countplot(data=z1,x='Has Online delivery')
plt.show()

# %%
sns.countplot(data=z1,x='Has Table booking')
plt.show()

# %%
sns.barplot(data=z1,x='Price range',y='Average Cost for two')
plt.show()

# %%
sns.boxplot(data=z1,x='Price range',y='Rating color',hue='Rating text')
plt.show()

# %%
z1['Price range'].value_counts().plot(kind='pie',autopct='%i%%',wedgeprops={'edgecolor':'k'})
plt.show()

# %%
q1=z1['Locality'].mode()[0]

# %%
q1
# Out:
# 'Connaught Place'

# %%
q1=z1[z1['Locality']=='Connaught Place']

# %%
q1
# Out:
#       Restaurant ID         Restaurant Name  Country Code       City  \
# 2999             53                   Amber             1  New Delhi
# 3000         307271  Attitude Kitchen & Bar             1  New Delhi
# 3001            596         Cafe Coffee Day             1  New Delhi
# 3002           1127                Castle 9             1  New Delhi
# 3003           4237            Costa Coffee             1  New Delhi
# ...             ...                     ...           ...        ...
# 3116            910     United Coffee House             1  New Delhi
# 3117       18216901     Unplugged Courtyard             1  New Delhi
# 3118         301114           Wenger's Deli             1  New Delhi
# 3119           4249                Wenger's             1  New Delhi
# 3120       18222559    {Niche} - Cafe & Bar             1  New Delhi
#
#                                                 Address         Locality  \
# ...

# %%
sns.histplot(data=q1,x='Average Cost for two',kde=True)
plt.show()

# %%
q1['Price range'].value_counts().plot(kind='pie',autopct='%i%%',wedgeprops={'edgecolor':'k','ls':'--'},shadow=True)
plt.show()

# %%
sns.countplot(data=q1,x='Has Online delivery')
plt.show()

# %%
df1=q1[(q1['Aggregate rating']<5)&(q1['Aggregate rating']>3)]
sns.boxplot(data=z1,x='Aggregate rating',y='Rating text')
plt.show()

# %%
sns.countplot(data=q1,x='Has Table booking')
plt.show()

# %%
sns.barplot(data=q1,x='Price range',y='Average Cost for two')
plt.show()

# %%
sns.boxplot(data=D1,x='Price range',y='Rating text',hue='Rating color')
plt.show()

# %%
q1.corr()
# Out:
#                       Restaurant ID  Country Code  Longitude  Latitude  \
# Restaurant ID              1.000000           NaN   0.215896  0.056859
# Country Code                    NaN           NaN        NaN       NaN
# Longitude                  0.215896           NaN   1.000000  0.059187
# Latitude                   0.056859           NaN   0.059187  1.000000
# Average Cost for two       0.092109           NaN  -0.100311 -0.225252
# Price range                0.053575           NaN  -0.132025 -0.080255
# Aggregate rating          -0.047095           NaN  -0.454648 -0.091782
# Votes                     -0.321164           NaN  -0.223362  0.068119
#
#                       Average Cost for two  Price range  Aggregate rating  \
# Restaurant ID                     0.092109     0.053575         -0.047095
# Country Code                           NaN          NaN               NaN
# Longitude                        -0.100311    -0.132025         -0.454648
# ...

# %%
sns.heatmap(data=q1.corr(),annot=True)
plt.show()

# %%
p1=q1['Cuisines'].mode()[0]

# %%
p1
# Out:
# 'North Indian, Mughlai'

# %%
c1=q1['Restaurant Name'].mode()[0]

# %%
c1
# Out:
# "Dunkin' Donuts"

# %%
sns.boxplot(data=q1,x='Aggregate rating',y='Rating color')
plt.show()

# %%
sns.boxplot(data=q1,x='Price range',y='Rating color',hue='Rating text')
plt.show()
